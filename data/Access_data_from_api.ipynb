# %% [markdown]
# This notebook explain how the incidence and climate data can be access through the mosqlimate api (https://api.mosqlimate.org/docs/datastore/).

# %%
import numpy as np 
import pandas as pd 
from mosqlient import get_infodengue, get_climate

# %% [markdown]
# Incidence data:

# %%
# return a pd.DataFrame with the data 

df = get_infodengue(

    start_date='2022-12-30', 

    end_date = '2023-01-30', 

    disease = 'dengue',

    uf = 'RJ') # uf represent the state level 

df.head()
# Out:
#    data_iniSE      SE  casos_est  casos_est_min  casos_est_max  casos  \
# 0  2023-01-29  202305        0.0              0              0      0
# 1  2023-01-29  202305        9.0              9              9      9
# 2  2023-01-29  202305        5.0              5              5      5
# 3  2023-01-29  202305        2.0              2              2      2
# 4  2023-01-29  202305        0.0              0              0      0
#
#    municipio_geocodigo     p_rt1  p_inc100k  Localidade_id  ...  nivel_inc  \
# 0              3301108  0.000000   0.000000              0  ...          0
# 1              3302502  0.761945   3.652108              0  ...          1
# 2              3306305  0.968967   1.824897              0  ...          0
# 3              3302106  0.880866   8.612523              0  ...          0
# 4              3305307  0.000000   0.000000              0  ...          0
#
#      umidmed    umidmin    tempmed    tempmax  casprov  casprov_est  \
# ...

# %% [markdown]
# Climate data:

# %%
# return a pd.DataFrame with the data 
df = get_climate(
    start_date='2022-12-30', 
    end_date = '2023-01-30',
    geocode = 3304557) # geocode represent the municipality level 


df.head()
# Out:
#          date  geocodigo  temp_min  temp_med  temp_max  precip_min  \
# 0  2022-12-30    3304557   22.2499   23.2568   24.2850      0.5377
# 1  2022-12-31    3304557   21.4598   23.9418   27.4797      0.0018
# 2  2023-01-01    3304557   22.4471   25.2049   28.6112      0.0000
# 3  2023-01-02    3304557   22.2306   25.8212   29.9726      0.0000
# 4  2023-01-03    3304557   23.3818   27.2378   32.1711      0.0000
#
#    precip_med  precip_max  precip_tot  pressao_min  pressao_med  pressao_max  \
# 0      0.9154      1.9040      7.3234       1.0013       1.0026       1.0040
# 1      0.3442      0.9423      2.7535       1.0012       1.0026       1.0042
# 2      0.4691      3.1281      3.7528       1.0000       1.0014       1.0031
# 3      0.2466      1.5756      1.9728       0.9954       0.9994       1.0019
# 4      0.0025      0.0141      0.0204       0.9940       0.9959       0.9974
#
#    umid_min  umid_med  umid_max
# 0   87.6209   91.7248   93.9398
# 1   73.3114   86.3707   93.7619
# ...
